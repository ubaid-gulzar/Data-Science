# %%
import matplotlib.pyplot as plt

# %%
oscar_movies  = [
    "the dark knight",
    "the hurt locker",
    "the kings speech",
    "the artist",
    "argo"
]
years = [2008,2009,2010,2011,2012]
oscar_revenue = [1005,170,427,133,232] # in million dollors

# %%
plt.barh(oscar_movies,oscar_revenue)
plt.title("Oscar Movies and their Revenues")
plt.xlabel("Oscar Movies")
plt.ylabel("Oscar Revenue(in $M)")
# Out:
# Text(0, 0.5, 'Oscar Revenue(in $M)')
