# %%
import numpy as np
import time

# %%
size = 10000

#python list time requirement to execute
py_list = list(range(size))
start = time.time()
sq_list = [x**2 for x in py_list]
end = time.time()
print("python list time =",end-start,"seconds")

#numpy array time requirement to execute
arr = np.array(py_list)
start = time.time()
sq_arr = arr ** 2
end  = time.time()
print("numpy array time =",end-start)
# Out:
# python list time = 0.007851839065551758 seconds
# numpy array time = 0.00038886070251464844
