# %%
import requests

# %%
URL = "https://www.scrapethissite.com/pages/simple/"
res = requests.get(URL)
res.status_code
# Out:
# 200

# %%
if res.status_code == 200:
   html_data = res.text

# %%
with open("03_scrapped_data.html", "w" ,encoding = "utf-8") as f:
    f.write(html_data)
