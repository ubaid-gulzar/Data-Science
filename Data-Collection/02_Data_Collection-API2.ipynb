# %%
import requests

# %%
URL = "https://dogapi.dog/api-docs/v2/swagger.json"
res = requests.get(URL)
res

# %%
json_data = res.json()
json_data
# Out:
# {'openapi': '3.0.1',
#  'info': {'title': 'API V2',
#   'version': '1.0.0',
#   'description': 'The Dog API provides a wealth of information on dog breeds, groups, and fun facts. Access and integrate this data into your website or application with our easy-to-use JSON API.',
#   'termsOfService': 'https://dogapi.dog/terms',
#   'contact': {'email': 'dev@dogapi.dog'},
#   'license': {'name': 'MIT',
#    'url': 'https://github.com/kinduff/dogapi.dog/blob/master/LICENSE'}},
#  'servers': [{'url': 'https://dogapi.dog/api/v2'}],
#  'paths': {'/breeds': {'get': {'summary': 'list breeds',
#     'tags': ['Breeds'],
#     'parameters': [{'name': 'page[number]',
#       'in': 'query',
#       'required': False,
#       'schema': {'type': 'integer', 'minimum': 1},
#       'description': 'Page number for pagination'},
#      {'name': 'page[size]',
#       'in': 'query',
#       'required': False,
#       'schema': {'type': 'integer', 'minimum': 1, 'maximum': 1000},
# ...

# %%
import pandas as pd

# %%
df = pd.json_normalize(json_data)
df
# Out:
#   openapi                                 servers info.title info.version  \
# 0   3.0.1  [{'url': 'https://dogapi.dog/api/v2'}]     API V2        1.0.0
#
#                                     info.description  \
# 0  The Dog API provides a wealth of information o...
#
#         info.termsOfService info.contact.email info.license.name  \
# 0  https://dogapi.dog/terms     dev@dogapi.dog               MIT
#
#                                     info.license.url  \
# 0  https://github.com/kinduff/dogapi.dog/blob/mas...
#
#   paths./breeds.get.summary  ...  paths./groups/{id}.get.summary  \
# 0               list breeds  ...  get group with non-existing id
#
#   paths./groups/{id}.get.tags  \
# 0                    [Groups]
#
#                    paths./groups/{id}.get.parameters  \
# 0  [{'name': 'id', 'in': 'path', 'required': True...
#
#   paths./groups/{id}.get.responses.200.description  \
# 0                                       successful
#
# ...
