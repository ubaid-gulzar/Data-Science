# %%
import requests

# %%
URL = "https://api.alquran.cloud/v1/quran/en.asad"

res = requests.get(URL)
res
# Out:
# <Response [200]>

# %%
json_data = res.json()

# %%
import pandas as pd

# %%
df = pd.json_normalize(json_data["data"])
df
# Out:
#                                               surahs edition.identifier  \
# 0  [{'number': 1, 'name': 'سُورَةُ ٱلْفَاتِحَةِ',...            en.asad
#
#   edition.language edition.name edition.englishName edition.format  \
# 0               en         Asad       Muhammad Asad           text
#
#   edition.type
# 0  translation

# %%
df.loc[0:2]
# Out:
#                                               surahs edition.identifier  \
# 0  [{'number': 1, 'name': 'سُورَةُ ٱلْفَاتِحَةِ',...            en.asad
#
#   edition.language edition.name edition.englishName edition.format  \
# 0               en         Asad       Muhammad Asad           text
#
#   edition.type
# 0  translation
