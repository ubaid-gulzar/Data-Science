# %%
import pandas as pd

# %%
df = pd.read_json("04_DataFrame_json.json")

# %%
#Methods
h = df.head()
print(h)
print(df.tail(2))
print("Random Row is:")
print(df.sample())
print(df.info())
print(df.shape)
print(df.describe())
print(df.columns)
print(df.nunique())
# Out:
#      name Dept  address
# 0   ubaid  CSE  Pulwama
# 1  kamran  ECE  Pulwama
# 2   sahil   CE  Pulwama
# 3  moshin  CSE  Pulwama
# 4   moien  CSE  Pulwama
#     name Dept  address
# 8  wahid   ME  Pulwama
# 9  Uzair   EE  Pulwama
# Random Row is:
#   name Dept  address
# 5  Ali  ECE  Pulwama
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     10 non-null     object
#  1   Dept     10 non-null     object
#  2   address  10 non-null     object
# dtypes: object(3)
# memory usage: 372.0+ bytes
# None
# (10, 3)
#          name Dept  address
# count      10   10       10
# unique     10    5        1
# top     ubaid  CSE  Pulwama
# freq        1    4       10
# Index(['name', 'Dept', 'address'], dtype='object')
# name       10
# Dept        5
# address     1
# dtype: int64
