# %%
import pandas as pd

# %%
df = pd.read_csv("18_visualisation.csv")
df
# Out:
#     id          name  age country   gender  income
# 0    1      john doe   29     usa     male   55000
# 1    1      john doe   29     usa     male   55000
# 2    2    jane smith   23  canada   female   62000
# 3    3          alex   64     usa  unknown   47000
# 4    4  maria garcia   43   spain   female   27000
# 5    5        li wei   27   china     male   51000
# 6    6           NaN   45   india   female   73000
# 7    7    ahmad khan   38     NaN     male   68000
# 8    8     rachellee   29     usa   female   62000
# 9    9   carlos ruiz   11  maxico     male   45000
# 10  10   emily davis   31     usa      NaN   58000

# %%
df["age"].hist()
# Out:
# <Axes: >

# %%
df.plot(kind = "scatter",x = "age",y = "income")
# Out:
# <Axes: xlabel='age', ylabel='income'>
