# %%
import pandas as pd

# %%
df = pd.read_csv("08_Data_cleaning.csv")
df
# Out:
#     id          name   age country   gender
# 0    1      john doe  29.0     usa     male
# 1    1      john doe  29.0     usa     male
# 2    2    jane smith   NaN  canada   female
# 3    3          alex   NaN     usa  unknown
# 4    4  maria garcia  43.0   spain   female
# 5    5        li wei  27.0   china     male
# 6    6           NaN  45.0   india   female
# 7    7    ahmad khan  38.0     NaN     male
# 8    8     rachellee  29.0     usa   female
# 9    9   carlos ruiz   NaN  maxico     male
# 10  10   emily davis  31.0     usa      NaN

# %%
df["gender"].str.lower()
df["gender"].str.upper()
df["gender"].str.capitalize()
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3     Unknown
# 4      Female
# 5        Male
# 6      Female
# 7        Male
# 8      Female
# 9        Male
# 10        NaN
# Name: gender, dtype: object

# %%
df["name"].str.strip()  #removes extra spaces
# Out:
# 0         john doe
# 1         john doe
# 2       jane smith
# 3             alex
# 4     maria garcia
# 5           li wei
# 6              NaN
# 7       ahmad khan
# 8        rachellee
# 9      carlos ruiz
# 10     emily davis
# Name: name, dtype: object

# %%
df["gender"].str.split("a")
# Out:
# 0       [m, le]
# 1       [m, le]
# 2     [fem, le]
# 3     [unknown]
# 4     [fem, le]
# 5       [m, le]
# 6     [fem, le]
# 7       [m, le]
# 8     [fem, le]
# 9       [m, le]
# 10          NaN
# Name: gender, dtype: object

# %%
df["country"].str.contains("US",case = False)
# Out:
# 0      True
# 1      True
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7       NaN
# 8      True
# 9     False
# 10     True
# Name: country, dtype: object
