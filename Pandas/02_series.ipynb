# %%
import pandas as pd

# %%
se = pd.Series([4,2,6,8,3,5])
print(se)
print(s[1])
# Out:
# 0    4
# 1    2
# 2    6
# 3    8
# 4    3
# 5    5
# dtype: int64
# 2

# %%
age = pd.Series([34,54,23,56],index = ["ubaid","Bob","Sahil","Faheem"])
print(age)
print(age[2])
print(age["Bob"])
print(age.index)
# Out:
# ubaid     34
# Bob       54
# Sahil     23
# Faheem    56
# dtype: int64
# 23
# 54
# Index(['ubaid', 'Bob', 'Sahil', 'Faheem'], dtype='object')
# C:\Users\hp\AppData\Local\Temp\ipykernel_7972\963265960.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(age[2])

# %%
#vectorized operations
s1 = pd.Series([1,2,3,4,5])
s2 = pd.Series([10,20,30,40,50])
print(s1 + s2)
print(s1 + 4)
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# 4    55
# dtype: int64
# 0    5
# 1    6
# 2    7
# 3    8
# 4    9
# dtype: int64

# %%
#mutable values but immutable size
s = pd.Series([1,2,3,4,5])
s[0] = 100
s2 = s1.drop(0)
print(s)
print(s2)
# Out:
# 0    100
# 1      2
# 2      3
# 3      4
# 4      5
# dtype: int64
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
