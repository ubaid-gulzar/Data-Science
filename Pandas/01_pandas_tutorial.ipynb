# %%
import pandas as pd

# %%
info = {
    "names" : ["ubaid","kamran","sahil"],
    "CGPA" : [9.5,9.9,5.5],
    "university" : "IUST"
}
df = pd.DataFrame(info)
print(df)
# Out:
#     names  CGPA university
# 0   ubaid   9.5       IUST
# 1  kamran   9.9       IUST
# 2   sahil   5.5       IUST
