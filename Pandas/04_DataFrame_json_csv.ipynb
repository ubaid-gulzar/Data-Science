# %%
import pandas as pd

# %%
# Creating DataFrame from csv file
df = pd.read_csv("04_DataFrame_csv.csv")
print(df)
# Out:
#      Name  Age      City
# 0   ubaid   22   Pulwama
# 1     Ali   43   Shopian
# 2  Kamran  2a5  Srinagar

# %%
# Creating DataFrame from json file
df = pd.read_json("04_DataFrame_json.json")
print(df)
# Out:
#      name Dept  address
# 0   ubaid  CSE  Pulwama
# 1  kamran  ECE  Pulwama
# 2   sahil   CE  Pulwama
# 3  moshin  CSE  Pulwama
# 4   moien  CSE  Pulwama
# 5     Ali  ECE  Pulwama
# 6  burhan   CE  Pulwama
# 7  Faheem  CSE  Pulwama
# 8   wahid   ME  Pulwama
# 9   Uzair   EE  Pulwama
