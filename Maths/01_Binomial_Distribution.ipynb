# %%
import numpy as np

# %%
#generate random binomial values

# %%
# n = number of trials, p = probability of success
n = 10
p = 0.5

# generate 8 random values
result = np.random.binomial(n, p, 8)     #RESULT RETURNS NUMBER OF SCCESSES
print(result)
# Out:
# [6 6 7 2 4 5 7 1]

# %%
from scipy.stats import binom

# %%
#calculate probability
n = 5
p = 0.5
k = 3      #successes
prob = binom.pmf(k, n, p)
print(prob)
# Out:
# 0.31249999999999983
